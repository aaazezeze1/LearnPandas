# %%
# Exploratory Data Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Amazing\Desktop\LearnPandas\world_population.csv")

# change the number format to 2 decimal places
# pd.set_option('display.float_format', lambda x: '%.2f' % x)

# get info of the data frame like how many columns 
# df.info()

# high level overview of all the columns and get the count, mean, sd, min and max, and percentiles
# df.describe()

# summary of how many missing (null) values are in each column of your DataFrame
# df.isnull().sum()

# show how many unique values are in each column
# df.nunique()

# get the top 10 largest countries
# df.sort_values(by="2022 Population", ascending=False).head(10)

# compare very column to each other and see how closely correlated they are
# print(df.select_dtypes(include='number').corr())

# create a heatmap themed graph of the correlation from before 
# sns.heatmap(df.select_dtypes(include='number').corr(), annot=True)

# %%
# make the graph larger
# the black on the graph means no correlation
# plt.rcParams['figure.figsize'] = (20, 8)
# plt.show() 

# check which continents have grown faster than others
# df.groupby('Continent').mean()

# Step 1: Group by continent and calculate mean for each column
# continent_df = df.groupby('Continent')[['Rank',
#     '1970 Population', '1980 Population', '1990 Population', '2000 Population',
#     '2010 Population', '2015 Population', '2020 Population', '2022 Population',
# ]].mean()

# Step 2: Calculate Growth Rate from 2010 to 2022
# continent_df['Growth Rate'] = (continent_df['2022 Population'] / continent_df['2010 Population']).round(2)

# Step 3 (optional): Population Percentage Growth
# continent_df['Pop Perc'] = ((continent_df['2022 Population'] - continent_df['2010 Population']) /
#                             continent_df['2010 Population']).round(2)

# Step 4: Reset index if you want to view it like a table
# continent_df = continent_df.reset_index()

# Step 5: Display it
# print(continent_df)

# Get all the countries inside the continent of oceania
# df[df['Continent'].str.contains('Oceania')]

# not working https://youtu.be/Mdq1WWSdUtw?si=cUn4WMu0o9jQhuo8&t=8863
# df.groupby('Continent').mean().sort_values(by="2022 Population", ascending=False)

# this is the same code
# Keep only numeric columns (like population and density, not text like Country or Capital)
numeric_cols = df.select_dtypes(include='number').columns

# Group the data by Continent, and compute the average (mean) for all numeric columns
df_grouped = df.groupby('Continent')[numeric_cols].mean()
df_grouped = df_grouped.sort_values(by="2022 Population", ascending=False)
print(df_grouped)

# %%
# visualize the data
df2 = pd.read_csv(r"C:\Users\Amazing\Desktop\LearnPandas\world_population.csv")
# df2 = numeric_cols = df.select_dtypes(include='number').columns
df_grouped = df2.groupby('Continent')[['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
       '2020 Population', '2015 Population', '2010 Population',
       '2000 Population', '1990 Population', '1980 Population',
       '1970 Population', 'Area (km²)', 'Density (per km²)']].mean()
df_grouped = df_grouped.sort_values(by="2022 Population", ascending=False)
# df_grouped.plot()

# code from the video
# df2 = df.groupby('Continent')[['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)']].mean().sort_values(by="2022 Population", ascending=False)

# continents become columns and the columns of the table becomes the index
df_grouped.transpose()
df_grouped.plot()

# %%
# Step 1: Select only numeric columns
numeric_cols = [
    '1970 Population', '1980 Population', '1990 Population',
    '2000 Population', '2010 Population', '2015 Population',
    '2020 Population', '2022 Population'
]

# Step 2: Group by continent and calculate the mean
df_grouped = df.groupby('Continent')[numeric_cols].mean()

# Step 3: Sort by 2022 population
df_grouped = df_grouped.sort_values(by="2022 Population", ascending=False)

# Step 4: Display the grouped data
print(df_grouped)

# Step 5: Optional - transpose for visualization
df_grouped.T.plot(figsize=(12, 6), title='Population and Area Metrics by Continent')
df_grouped.transpose()

# %%
# Box plot for outliers
# df.boxplot(figsize=(20, 10))

# check the types of values inside the columns
# df.dtypes()

# only return columns with numbers
# df.select_dtypes(include='number')

# only return columns with strings
# df.select_dtypes(include='object')

# only return columns with float numbers
df.select_dtypes(include='float')
